# %%
# %sql
USE CATALOG 100cep_gateway;

# %%
# %sql
USE SCHEMA bronze;

# %%
# %sql

COMMENT ON TABLE 100cep_customers_raw IS 'The table contains detailed information about customers, including unique identifiers, location, and registration data. All data originates from the olist dataset. / A tabela contém informações detalhadas sobre os clientes, incluindo identificadores únicos, localização e dados de cadastro. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_geolocation_raw IS 'The table contains geolocation data for customer addresses, such as latitude, longitude, and zip code mapping. All data originates from the olist dataset. / A tabela contém dados de geolocalização dos endereços dos clientes, como latitude, longitude e mapeamento de CEP. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_order_items_raw IS 'The table contains details of each item in all orders, such as product, seller, shipping dates, and pricing. All data originates from the olist dataset. / A tabela contém detalhes de cada item em todos os pedidos, como produto, vendedor, datas de envio e preços. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_order_payments_raw IS 'The table contains payment information for orders, including payment type, installments, and transaction values. All data originates from the olist dataset. / A tabela contém informações de pagamento dos pedidos, incluindo tipo de pagamento, parcelas e valores das transações. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_order_items_raw IS 'The table contains details of each item in all orders, such as product, seller, shipping dates, and pricing. All data originates from the olist dataset. / A tabela contém detalhes de cada item em todos os pedidos, como produto, vendedor, datas de envio e preços. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_order_payments_raw IS 'The table contains payment information for orders, including payment type, installments, and transaction values. All data originates from the olist dataset. / A tabela contém informações de pagamento dos pedidos, incluindo tipo de pagamento, parcelas e valores das transações. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_order_reviews_raw IS 'The table contains customer reviews for orders, including ratings, comments, and review timestamps. All data originates from the olist dataset. / A tabela contém avaliações dos clientes sobre os pedidos, incluindo notas, comentários e datas das avaliações. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_orders_raw IS 'The table contains information about customer orders, including order status, timestamps, and customer-seller relationships. All data originates from the olist dataset. / A tabela contém informações sobre os pedidos dos clientes, incluindo status do pedido, datas e relacionamento cliente-vendedor. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_products_raw IS 'The table contains product information, including product identifiers, category, and descriptive attributes. All data originates from the olist dataset. / A tabela contém informações sobre os produtos, incluindo identificadores, categoria e atributos descritivos. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_sellers_raw IS 'The table contains information about sellers, including unique identifiers, location, and contact details. All data originates from the olist dataset. / A tabela contém informações sobre os vendedores, incluindo identificadores únicos, localização e dados de contato. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_product_category_name_translation_raw IS 'The table contains translations for product category names, mapping Portuguese names to English equivalents. All data originates from the olist dataset. / A tabela contém traduções para os nomes das categorias de produtos, relacionando nomes em português aos equivalentes em inglês. Todos os dados vêm do dataset olist.';

COMMENT ON TABLE 100cep_chargebacks_raw IS 'The table contains chargeback information for orders, including reason, status, and dates. All data was generated with support from the OpenAI model 5.0. / A tabela contém informações sobre chargebacks dos pedidos, incluindo motivo, status e datas. Todos os dados foram originados com apoio do modelo 5.0 da OpenAI.';

# %%
# %sql
USE SCHEMA silver;

# %%
# %sql
COMMENT ON TABLE 100cep_avaliacoes IS "The table contains customer reviews for orders, including ratings, comments, and review timestamps. All data originates from the olist dataset. / A tabela contém avaliações dos clientes sobre os pedidos, incluindo notas, comentários e datas das avaliações. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_categoria_produtos IS "The table contains product category information, including category identifiers and descriptive names in both Portuguese and English. All data originates from the olist dataset. / A tabela contém informações sobre categorias de produtos, incluindo identificadores de categoria e nomes descritivos em português e inglês. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_chargebacks IS "The table contains chargeback information for orders, including reason, status, and relevant dates. All data was generated with support from the OpenAI model 5.0. / A tabela contém informações sobre chargebacks dos pedidos, incluindo motivo, status e datas relevantes. Todos os dados foram originados com apoio do modelo 5.0 da OpenAI.";

COMMENT ON TABLE 100cep_geolocalizacao IS "The table contains geolocation data for customer and seller addresses, such as latitude, longitude, city, state, and zip code mapping. All data originates from the olist dataset. / A tabela contém dados de geolocalização dos endereços de clientes e vendedores, como latitude, longitude, cidade, estado e mapeamento de CEP. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_itens_pedidos IS "The table contains details of each item in all orders, including product, seller, delivery deadlines, and pricing information. All data originates from the olist dataset. / A tabela contém detalhes de cada item em todos os pedidos, incluindo produto, vendedor, prazos de entrega e informações de preços. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_pagamentos IS "The table contains payment information for orders, including payment type, number of installments, and transaction values. All data originates from the olist dataset. / A tabela contém informações de pagamento dos pedidos, incluindo tipo de pagamento, número de parcelas e valores das transações. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_produtos IS "The table contains product information, including product identifiers, category, and descriptive attributes. All data originates from the olist dataset. / A tabela contém informações sobre os produtos, incluindo identificadores, categoria e atributos descritivos. Todos os dados vêm do dataset olist.";

COMMENT ON TABLE 100cep_vendedores IS "The table contains information about sellers, including unique identifiers, location, and contact details. All data originates from the olist dataset. / A tabela contém informações sobre os vendedores, incluindo identificadores únicos, localização e dados de contato. Todos os dados vêm do dataset olist.";

# %%
# %sql
USE SCHEMA gold;

# %%
# %sql
COMMENT ON TABLE dim_chargebacks IS "This table contains detailed information about chargebacks in transactions, including reasons, statuses, and relevant dates. It is curated in the gold layer of the pipeline for advanced analytics and reporting. / Esta tabela contém informações detalhadas sobre chargebacks em transações, incluindo motivos, status e datas relevantes. Ela é organizada na camada gold do pipeline para análises avançadas e relatórios.";

COMMENT ON TABLE dim_clientes IS "This table provides enriched customer data, including unique identifiers, location, and registration details. It is maintained in the gold layer for high-quality business intelligence and customer segmentation. / Esta tabela fornece dados enriquecidos dos clientes, incluindo identificadores únicos, localização e detalhes de cadastro. Ela é mantida na camada gold para inteligência de negócios de alta qualidade e segmentação de clientes.";

COMMENT ON TABLE dim_data IS "This table offers a comprehensive calendar dimension, including dates, day names, month names, and year information. It is stored in the gold layer to support time-based analysis and reporting. / Esta tabela oferece uma dimensão de calendário abrangente, incluindo datas, nomes dos dias, nomes dos meses e informações de ano. Ela está armazenada na camada gold para apoiar análises e relatórios baseados em tempo.";

COMMENT ON TABLE dim_geolocalizacao IS "This table contains geolocation data for addresses, such as city, state, latitude, longitude, and zip code prefix. Curated in the gold layer, it enables geographic analysis and location-based insights. / Esta tabela contém dados de geolocalização de endereços, como cidade, estado, latitude, longitude e prefixo de CEP. Organizada na camada gold, ela possibilita análises geográficas e insights baseados em localização.";

COMMENT ON TABLE dim_vendedores IS "This table contains enriched seller information, including unique identifiers, location, and contact details. Maintained in the gold layer, it supports advanced seller analytics and performance tracking. / Esta tabela contém informações enriquecidas dos vendedores, incluindo identificadores únicos, localização e dados de contato. Mantida na camada gold, ela apoia análises avançadas de vendedores e acompanhamento de desempenho.";

COMMENT ON TABLE fato_transacoes IS "This table records transactional facts, integrating data from multiple dimensions such as customers, sellers, payments, and products. Stored in the gold layer, it is optimized for business analysis and decision-making. / Esta tabela registra fatos transacionais, integrando dados de várias dimensões como clientes, vendedores, pagamentos e produtos. Armazenada na camada gold, ela é otimizada para análise de negócios e tomada de decisão.";
